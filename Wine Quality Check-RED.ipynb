# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
red=pd.read_csv(r'C:\Users\Vatsal\Desktop\projects\Data Sets\Self\Wine Quality\winequality-red.csv', sep= ';')
print(red.shape)
red.head()
# Out:
# (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %%
df=pd.DataFrame(red)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.rename(columns={'fixed acidity':'fixed_acidity',
                   'volatile acidity':'volatile_acidity','citric acid':'citric_acid',
                   'residual sugar':'residual_sugar','free sulfur dioxide':'free_sulphur_dioxide',
                   'total sulfur dioxide':'total_sulphur_dioxide'}, inplace=True)

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulphur_dioxide  total_sulphur_dioxide      density  \
# count  1599.000000           1599.000000            1599.000000  1599.000000
# mean      0.087467             15.874922              46.467792     0.996747
# std       0.047065             10.460157              32.895324     0.001887
# ...

# %%
df.corr()
# Out:
#                        fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity               1.000000         -0.256131     0.671703
# volatile_acidity           -0.256131          1.000000    -0.552496
# citric_acid                 0.671703         -0.552496     1.000000
# residual_sugar              0.114777          0.001918     0.143577
# chlorides                   0.093705          0.061298     0.203823
# free_sulphur_dioxide       -0.153794         -0.010504    -0.060978
# total_sulphur_dioxide      -0.113181          0.076470     0.035533
# density                     0.668047          0.022026     0.364947
# pH                         -0.682978          0.234937    -0.541904
# sulphates                   0.183006         -0.260987     0.312770
# alcohol                    -0.061668         -0.202288     0.109903
# quality                     0.124052         -0.390558     0.226373
#
#                        residual_sugar  chlorides  free_sulphur_dioxide  \
# ...

# %%
corrmat = df.corr()

f, ax = plt.subplots(figsize =(6, 5)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed_acidity            0
# volatile_acidity         0
# citric_acid              0
# residual_sugar           0
# chlorides                0
# free_sulphur_dioxide     0
# total_sulphur_dioxide    0
# density                  0
# pH                       0
# sulphates                0
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.plot(kind='box')

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
low = Q1-1.5*IQR
high = Q3+1.5*IQR
print(high)
print()
print(low)
# Out:
# fixed_acidity             12.350000
# volatile_acidity           1.015000
# citric_acid                0.915000
# residual_sugar             3.650000
# chlorides                  0.120000
# free_sulphur_dioxide      42.000000
# total_sulphur_dioxide    122.000000
# density                    1.001187
# pH                         3.685000
# sulphates                  1.000000
# alcohol                   13.500000
# quality                    7.500000
# dtype: float64
#
# fixed_acidity             3.950000
# volatile_acidity          0.015000
# citric_acid              -0.405000
# residual_sugar            0.850000
# chlorides                 0.040000
# free_sulphur_dioxide    -14.000000
# total_sulphur_dioxide   -38.000000
# density                   0.992248
# pH                        2.925000
# sulphates                 0.280000
# alcohol                   7.100000
# quality                   3.500000
# dtype: float64

# %%
((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
# Out:
# fixed_acidity             49
# volatile_acidity          19
# citric_acid                1
# residual_sugar           155
# chlorides                112
# free_sulphur_dioxide      30
# total_sulphur_dioxide     55
# density                   45
# pH                        35
# sulphates                 59
# alcohol                   13
# quality                   28
# dtype: int64

# %% [markdown]
# In the above two boxes
# The first box is used to find the Q1, Q3, and IQR values.
# The second box gives the sum total of outliers in each variable

# %% [markdown]
# Outlier Treatment.

# %%
print(df.quantile(0.95)) 
print()
print(df.quantile(0.50))
# Out:
# fixed_acidity             11.8000
# volatile_acidity           0.8400
# citric_acid                0.6000
# residual_sugar             5.1000
# chlorides                  0.1261
# free_sulphur_dioxide      35.0000
# total_sulphur_dioxide    112.1000
# density                    1.0000
# pH                         3.5700
# sulphates                  0.9300
# alcohol                   12.5000
# quality                    7.0000
# Name: 0.95, dtype: float64
#
# fixed_acidity             7.90000
# volatile_acidity          0.52000
# citric_acid               0.26000
# residual_sugar            2.20000
# chlorides                 0.07900
# free_sulphur_dioxide     14.00000
# total_sulphur_dioxide    38.00000
# density                   0.99675
# pH                        3.31000
# sulphates                 0.62000
# alcohol                  10.20000
# quality                   6.00000
# Name: 0.5, dtype: float64

# %%
#Outlier treatment - Replacing outliers with Median
df['fixed_acidity'] = np.where(df['fixed_acidity'] > 11.80, 7.90, df['fixed_acidity'])
df['volatile_acidity'] = np.where(df['volatile_acidity'] > 0.84, 0.52, df['volatile_acidity'])
df['citric_acid'] = np.where(df['citric_acid'] > 0.60, 0.26, df['citric_acid'])
df['residual_sugar'] = np.where(df['residual_sugar'] > 5.10, 2.20, df['residual_sugar'])
df['chlorides'] = np.where(df['chlorides'] > 0.126, 0.079, df['chlorides'])
df['free_sulphur_dioxide'] = np.where(df['free_sulphur_dioxide'] > 35, 14, df['free_sulphur_dioxide'])
df['total_sulphur_dioxide'] = np.where(df['total_sulphur_dioxide'] > 112, 38, df['total_sulphur_dioxide'])
#df['density'] = np.where(df['density'] > 1, 0.99, df['density'])
df['pH'] = np.where(df['pH'] > 3.57, 3.31, df['pH'])
df['sulphates'] = np.where(df['sulphates'] > 0.93, 0.62, df['sulphates'])
df['alcohol'] = np.where(df['alcohol'] > 12.50, 10.20, df['alcohol'])

# %% [markdown]
# The values for density is left untreated because the values are between (0.99-1.00) and treating them increases the number of outliers present.

# %% [markdown]
# In the above technique, we replace the extreme values with median values.
# It is advised to not use mean values as they are affected by outliers.
# The first line of code below prints the 50th percentile value, or the median.
# The second line prints the 95th percentile value.
# The third line of code below replaces all those values in the variable, which are greater than the 95th percentile, with the median value.

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.079425          0.506548     0.250607        2.279049
# std         1.394153          0.147163     0.171230        0.618447
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         8.900000          0.610000     0.390000        2.500000
# max        11.800000          0.840000     0.600000        5.100000
#
#          chlorides  free_sulphur_dioxide  total_sulphur_dioxide      density  \
# count  1599.000000           1599.000000            1599.000000  1599.000000
# mean      0.079135             14.441839              41.575360     0.996747
# std       0.015677              8.176751              25.026171     0.001887
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
# Out:
# fixed_acidity             6
# volatile_acidity          0
# citric_acid               0
# residual_sugar           90
# chlorides                79
# free_sulphur_dioxide      0
# total_sulphur_dioxide    30
# density                  45
# pH                       22
# sulphates                10
# alcohol                   0
# quality                  28
# dtype: int64

# %%
df.boxplot()

# %% [markdown]
# The outliers have been reduced but are seen again because the range of quartiles have shifted.

# %%
print(df.quantile(0.95)) 
print()
print(df.quantile(0.50))
# Out:
# fixed_acidity            10.700
# volatile_acidity          0.750
# citric_acid               0.530
# residual_sugar            3.600
# chlorides                 0.109
# free_sulphur_dioxide     31.000
# total_sulphur_dioxide    93.100
# density                   1.000
# pH                        3.511
# sulphates                 0.850
# alcohol                  12.000
# quality                   7.000
# Name: 0.95, dtype: float64
#
# fixed_acidity             7.90000
# volatile_acidity          0.52000
# citric_acid               0.26000
# residual_sugar            2.20000
# chlorides                 0.07900
# free_sulphur_dioxide     14.00000
# total_sulphur_dioxide    38.00000
# density                   0.99675
# pH                        3.31000
# sulphates                 0.62000
# alcohol                  10.20000
# quality                   6.00000
# Name: 0.5, dtype: float64

# %%
df['residual_sugar'] = np.where(df['residual_sugar'] > 3.60, 2.20, df['residual_sugar'])
df['chlorides'] = np.where(df['chlorides'] > 0.109, 0.079, df['chlorides'])
df['total_sulphur_dioxide'] = np.where(df['total_sulphur_dioxide'] > 93.10, 38, df['total_sulphur_dioxide'])
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.079425          0.506548     0.250607        2.180894
# std         1.394153          0.147163     0.171230        0.425261
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         8.900000          0.610000     0.390000        2.400000
# max        11.800000          0.840000     0.600000        3.600000
#
#          chlorides  free_sulphur_dioxide  total_sulphur_dioxide      density  \
# count  1599.000000           1599.000000            1599.000000  1599.000000
# mean      0.077305             14.441839              38.358349     0.996747
# std       0.013157              8.176751              20.747320     0.001887
# ...

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).sum()
# Out:
# fixed_acidity             6
# volatile_acidity          0
# citric_acid               0
# residual_sugar           54
# chlorides                71
# free_sulphur_dioxide      0
# total_sulphur_dioxide    22
# density                  45
# pH                       22
# sulphates                10
# alcohol                   0
# quality                  28
# dtype: int64

# %% [markdown]
# Generating graphs and visuals

# %%
sns.boxplot(data=df)

# %%
sns.pairplot(df, hue='quality')

# %%
plt.bar(df['quality'], df['total_sulphur_dioxide']) 
plt.xlabel("Quality")
plt.ylabel("Total Sulphur di-oxide")
plt.show()

# %%
plt.scatter(df['sulphates'], df['chlorides']) 
plt.show()

# %%
df.hist(edgecolor='black', linewidth=1.1, figsize=(13,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BE450E9548>,
# ...
#       dtype=object)

# %% [markdown]
# Feature Engineering.

# %%
df['remark'] = df['quality'].map({3 :'Average', 4 :'Average', 5 :'Good', 6 :'Good', 7 :'Great', 8 :'Great'})

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.52         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulphur_dioxide  total_sulphur_dioxide  density    pH  sulphates  \
# 0                  11.0                   34.0   0.9978  3.51       0.56
# 1                  25.0                   67.0   0.9968  3.20       0.68
# 2                  15.0                   54.0   0.9970  3.26       0.65
# 3                  17.0                   60.0   0.9980  3.16       0.58
# 4                  11.0                   34.0   0.9978  3.51       0.56
#
#    alcohol  quality remark
# 0      9.4        5   Good
# ...

# %%
df.drop(['quality'], axis = 1, inplace = True)
print(df.shape)
df.head()
# Out:
# (1599, 12)
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.52         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulphur_dioxide  total_sulphur_dioxide  density    pH  sulphates  \
# 0                  11.0                   34.0   0.9978  3.51       0.56
# 1                  25.0                   67.0   0.9968  3.20       0.68
# 2                  15.0                   54.0   0.9970  3.26       0.65
# 3                  17.0                   60.0   0.9980  3.16       0.58
# 4                  11.0                   34.0   0.9978  3.51       0.56
#
#    alcohol remark
# 0      9.4   Good
# 1      9.8   Good
# ...

# %%
df.rename(columns={'remark':'Quality'}, inplace=True)

# %%
colname =[]
for j in df.columns[:]:
    if df[j].dtype == 'object':
        colname.append(j)

colname
# Out:
# []

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

for j in colname:
    df[j] = le.fit_transform(df[j].astype(str))

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.52         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulphur_dioxide  total_sulphur_dioxide  density    pH  sulphates  \
# 0                  11.0                   34.0   0.9978  3.51       0.56
# 1                  25.0                   67.0   0.9968  3.20       0.68
# 2                  15.0                   54.0   0.9970  3.26       0.65
# 3                  17.0                   60.0   0.9980  3.16       0.58
# 4                  11.0                   34.0   0.9978  3.51       0.56
#
#    alcohol  Quality
# 0      9.4        1
# 1      9.8        1
# ...

# %%
df['Quality'].value_counts()
# Out:
# 1    1319
# 2     217
# 0      63
# Name: Quality, dtype: int64

# %%
X = df.values[:,:-1]
Y = df.values[:,-1]
Y = Y.astype(int)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X)

X = scaler.transform(X)
print(X)
# Out:
# [[-0.48749109  1.31495678 -1.46402501 ...  1.61934892 -0.63390819
#   -1.00104746]
#  [-0.20048879  0.09143866 -1.46402501 ... -0.7168514   0.42997971
#   -0.55464336]
#  [-0.20048879  1.72279615 -1.23034803 ... -0.26468359  0.16400773
#   -0.55464336]
#  ...
#  [-1.27674742  0.02346543 -0.70457482 ...  0.94109722  1.05058098
#    0.78456893]
#  [-1.56374972  0.94110402 -0.76299407 ...  2.07151673  0.69595168
#   -0.10823927]
#  [-1.49199915 -1.33599915  1.28167951 ...  0.71501332  0.25266506
#    0.78456893]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.3, random_state = 10)

# %% [markdown]
# # Logistic Regression

# %%
#Building the model
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression() # creating the model object
#Fitting the training data in the model
classifier.fit(X_train,Y_train)
Y_pred = classifier.predict(X_test)
#print(list(zip(Y_test,Y_pred)))

print(classifier.coef_)
print(classifier.intercept_)
# Out:
# [[-0.22324509  0.05090862 -0.4438156  -0.1949303  -0.14443058 -0.30035781
#   -0.11937574  0.41246469 -0.04979345 -0.78959689  0.22027545]
#  [-0.21600095  0.39334466  0.32536139 -0.07628168  0.20252994  0.19274435
#    0.1946101   0.16291953  0.12317101 -0.37357579 -0.53347298]
#  [ 0.26256299 -0.5965585  -0.25618859  0.16563743 -0.1716561  -0.09319052
#   -0.21271542 -0.30046261 -0.21445193  0.73095388  0.6654027 ]]
# [-3.57209089  1.88658278 -2.63641388]

# %%
#Evaluating the model

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cfm= confusion_matrix (Y_test,Y_pred)
print(cfm)

print("Classification report: ")

print(classification_report(Y_test,Y_pred))

acc=accuracy_score(Y_test,Y_pred)
print("Accuracy of the model:",acc)
# Out:
# [[  0  18   0]
#  [  0 379  14]
#  [  0  54  15]]
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.84      0.96      0.90       393
#            2       0.52      0.22      0.31        69
#
#     accuracy                           0.82       480
#    macro avg       0.45      0.39      0.40       480
# weighted avg       0.76      0.82      0.78       480
#
# Accuracy of the model: 0.8208333333333333

# %% [markdown]
# # Naive Bayes

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, Y_train)

Y_pred_NB= classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, Y_pred_NB))
print(confusion_matrix(Y_test, Y_pred_NB))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(Y_pred_NB,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.89      0.85      0.87       393
#            2       0.48      0.61      0.54        69
#
#     accuracy                           0.79       480
#    macro avg       0.45      0.49      0.47       480
# weighted avg       0.79      0.79      0.79       480
#
# [[  0  18   0]
#  [ 12 335  46]
#  [  2  25  42]]
# accuracy is 0.7854166666666667

# %% [markdown]
# # Support Vector Classification

# %%
from sklearn.svm import SVC

classifier = SVC()
classifier.fit(X_train, Y_train)

y_pred_SVM = classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, y_pred_SVM))
print(confusion_matrix(Y_test, y_pred_SVM))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred_SVM,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        18
#            1       0.85      0.97      0.91       393
#            2       0.62      0.26      0.37        69
#
#     accuracy                           0.83       480
#    macro avg       0.49      0.41      0.42       480
# weighted avg       0.78      0.83      0.79       480
#
# [[  0  18   0]
#  [  0 382  11]
#  [  0  51  18]]
# accuracy is 0.8333333333333334

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors=3)
classifier.fit(X_train, Y_train)

y_pred_KNN = classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, y_pred_KNN))
print(confusion_matrix(Y_test, y_pred_KNN))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred_KNN,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.11      0.14        18
#            1       0.87      0.90      0.88       393
#            2       0.47      0.41      0.44        69
#
#     accuracy                           0.80       480
#    macro avg       0.51      0.47      0.49       480
# weighted avg       0.78      0.80      0.79       480
#
# [[  2  16   0]
#  [  7 355  31]
#  [  2  39  28]]
# accuracy is 0.8020833333333334

# %% [markdown]
# # Decision Tree

# %%
# Decision Tree's
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()

classifier.fit(X_train, Y_train)

y_pred_DT = classifier.predict(X_test)

# Summary of the predictions made by the classifier
print(classification_report(Y_test, y_pred_DT))
print(confusion_matrix(Y_test, y_pred_DT))
# Accuracy score
from sklearn.metrics import accuracy_score
print('accuracy is',accuracy_score(y_pred_DT,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.17      0.15        18
#            1       0.89      0.89      0.89       393
#            2       0.59      0.55      0.57        69
#
#     accuracy                           0.81       480
#    macro avg       0.54      0.54      0.54       480
# weighted avg       0.82      0.81      0.82       480
#
# [[  3  15   0]
#  [ 17 350  26]
#  [  2  29  38]]
# accuracy is 0.8145833333333333
